# %%
import pandas as pd
df = pd.read_csv("alpaca_sample_data.csv")
print(df.dtypes)
# Out:
# symbol          object
# timestamp       object
# open           float64
# high           float64
# low            float64
# close          float64
# volume         float64
# trade_count    float64
# vwap           float64
# dtype: object
